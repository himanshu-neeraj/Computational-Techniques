# %%
#Finding the mean

lower_class = [15, 25, 35, 45, 55]
upper_class = [25, 35, 45, 55, 65]
f = [350, 375, 120, 80, 90]
fx = []

for i in range(5):
    x = (lower_class[i] + upper_class[i]) / 2  
    prod = x * f[i]
    fx.append(prod)

sum_fx = sum(fx)
sum_f = sum(f)
mean = sum_fx / sum_f

print("Mean =", mean)


#Finding the median

lower = [15, 25, 35, 45, 55]
upper = [25, 35, 45, 55, 65]
f = [350, 375, 120, 80, 90]

N = sum(f)
half = N / 2

cf = []
temp = 0
for i in f:
    temp += i
    cf.append(temp)

for i in range(len(cf)):
    if cf[i] >= half:
        L = lower[i]
        F = cf[i-1] if i > 0 else 0
        f_m = f[i]
        h = upper[i] - lower[i]
        break

median = L + ((half - F) / f_m) * h

print("Median =", median)


#Finding the mode

lower = [15, 25, 35, 45, 55]
upper = [25, 35, 45, 55, 65]
f = [350, 375, 120, 80, 90]

max_f = max(f)                
m = f.index(max_f)            

L = lower[m]                
f1 = f[m]                    
f0 = f[m - 1] if m > 0 else 0  
# Aapki line
f2 = f[m + 1] if m > 0 else 0
h = upper[m] - lower[m]      

mode = L + ((f1 - f0) / ((2 * f1) - f0 - f2)) * h

print("Mode =", mode)
# Out:
# Mean = 31.970443349753694
# Median = 29.2
# Mode = 25.892857142857142
